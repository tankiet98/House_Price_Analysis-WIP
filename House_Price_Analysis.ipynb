# %% [markdown]
# ## **House Price Analysis**
#
# The primary goal of the House Price Analysis project is to develop a robust model that can systematically analyze various factors influencing house prices in different areas. By leveraging Python for data visualization and analysis, the project aims to provide insights into the key variables affecting property values and determine reasonable pricing based on prevailing conditions.

# %% [markdown]
# #### **1. Data Pre-processing**
#  - 1.1 Import librabries
#  - 1.2 Read files
#  - 1.3 Check null, NA, unique and duplicated values

# %%
# Import librabries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme()

# %%
# Read files
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Project_raw_data/HousePrice_Analysis/HousePrice_Prediction.xlsx', sheet_name='df')

# %%
df.head()
# Out:
#    id mszoning  lotarea lotshape street bldgtype  overallcond  yearbuilt  \
# 0   0       RL     8450      Reg   Pave     1Fam            5       2003
# 1   1       RL     9600      Reg   Pave     1Fam            8       1976
# 2   2       RL    11250      IR1   Pave     1Fam            5       2001
# 3   3       RL     9550      IR1   Pave     1Fam            5       1915
# 4   4       RL    14260      IR1   Pave     1Fam            5       2000
#
#    yearremodadd exterior1st  totalbsmtsf  overallqual roofstyle  saleprice
# 0          2003     VinylSd          856            7     Gable     208500
# 1          1976     VinylSd         1262            6     Gable     181500
# 2          2002         NaN          920            7     Gable     223500
# 3          1970     Wd Sdng          756            7     Gable     140000
# 4          2000     VinylSd         1145            8     Gable     250000
